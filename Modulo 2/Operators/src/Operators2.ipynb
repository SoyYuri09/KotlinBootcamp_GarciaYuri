// %%
val fish = 2
fish.times( other = 6)
fish.div( other = 10)
fish.plus( other = 3)
fish.minus( other = 3)
// Out:
// -1

// %%
// usar tipos primitivos 'int' como un objeto
1.toLong()
// Out:
// 1

// %%
val boxed: Number = 1
boxed.toLong()
// Out:
// 1
